# %% [markdown]
# # Exploring the eyecite library

# %% [markdown]
# This purpose of this notebook is to explore the eyecite module ([documentation](https://freelawproject.github.io/eyecite/)). This module is supposed to find citations in legal documents.

# %%
import eyecite

# %% [markdown]
# We know the module was created and used by CAP. So it stands to reason that things which are true about CAP's front end are going to be true about the library itself. One problem with CAP is that it doesn't not recognize antique reporters. For instance, we know that Kelly is an early version of the Georgia Reports. So let's create some dummy text and see if we can find the citations.

# %%
text = """
    This principle was established in 3 Kelly 234. That citation is equivalent to 3 Ga. 234. 
    It was also established in 12 U.S. 534. 
"""

cites = eyecite.get_citations(text)
print(f"We found {len(cites)} citations.")
# Out:
# We found 2 citations.

# %% [markdown]
# So as expected, we found 2 citations rather than 3. Let's look at each of the citations.

# %%
print(cites[0])
print(cites[1])
# Out:
# FullCaseCitation('3 Ga. 234', groups={'volume': '3', 'reporter': 'Ga.', 'page': '234'}, metadata=FullCaseCitation.Metadata(parenthetical=None, pin_cite=None, year=None, court=None, plaintiff=None, defendant=None, extra=None))
# FullCaseCitation('12 U.S. 534', groups={'volume': '12', 'reporter': 'U.S.', 'page': '534'}, metadata=FullCaseCitation.Metadata(parenthetical=None, pin_cite=None, year=None, court='scotus', plaintiff=None, defendant=None, extra=None))

# %% [markdown]
# So we found two citations: the Georgia one (not the Kelly one) and the U.S. one. Note that eyecite figured out that `U.S.` meant that the court is `scotus`.
#
# We can note that it also knows that the repoort is "Georgia Reports," that it is a state reporter from Georgia, and that the start date for that reporter is 1846.

# %%
ga = cites[0]
ga.all_editions
# Out:
# (Edition(reporter=Reporter(short_name='Ga.', name='Georgia Reports', cite_type='state', source='reporters', is_scotus=False), short_name='Ga.', start=datetime.datetime(1846, 1, 1, 0, 0), end=None),)

# %% [markdown]
# This might imply that if we teach eyecite about Kelly, it will be able to pick it up.
#
# We can also try to resolve the citations. Let's do it for these.

# %%
res = eyecite.resolve_citations(cites)
res
# Out:
# defaultdict(list,
#             {Resource(citation=FullCaseCitation('3 Ga. 234', groups={'volume': '3', 'reporter': 'Ga.', 'page': '234'}, metadata=FullCaseCitation.Metadata(parenthetical=None, pin_cite=None, year=None, court=None, plaintiff=None, defendant=None, extra=None))): [FullCaseCitation('3 Ga. 234', groups={'volume': '3', 'reporter': 'Ga.', 'page': '234'}, metadata=FullCaseCitation.Metadata(parenthetical=None, pin_cite=None, year=None, court=None, plaintiff=None, defendant=None, extra=None))],
#              Resource(citation=FullCaseCitation('12 U.S. 534', groups={'volume': '12', 'reporter': 'U.S.', 'page': '534'}, metadata=FullCaseCitation.Metadata(parenthetical=None, pin_cite=None, year=None, court='scotus', plaintiff=None, defendant=None, extra=None))): [FullCaseCitation('12 U.S. 534', groups={'volume': '12', 'reporter': 'U.S.', 'page': '534'}, metadata=FullCaseCitation.Metadata(parenthetical=None, pin_cite=None, year=None, court='scotus', plaintiff=None, defendant=None, extra=None))]})

# %% [markdown]
# This is apparently something you have to extend yourself.

# %% [markdown]
# ## Exploring the module itself

# %% [markdown]
# We can see the various regexes that are used. For example.

# %%
print(eyecite.regexes.POST_FULL_CITATION_REGEX)
# Out:
#     (?:  # handle a full cite with a valid year paren:
#         # content before year paren:
#         (?:
#             # pin cite with comma and extra:
#
#     (?P<pin_cite>
#         # optional comma, space, "at" before pin cite
#         ,?\ ?(?:at\ )?
#         # first mandatory page number
#
#     # optional label (longest to shortest):
#     (?:
#         (?:
#             (?:&\ )?note|       # note, & note
#             (?:&\ )?nn?\.?|     # n., nn., & nn.
#             (?:&\ )?fn?\.?|     # fn., & fn.
#             ¶{1,2}|             # ¶
#             §{1,2}|             # §
#             \*{1,4}|            # *
#             pg\.?|              # pg.
#             pp?\.?              # p., pp.
#         )\ ?  # optional space after label
#     )?
#     (?:
#         # page:paragraph cite, like 123:24-25 or 123:24-124:25:
#         \d+:\d+(?:-\d+(?::\d+)?)?|
#         # page range, like 12 or 12-13:
#         \d+(?:-\d+)?
#     )
#
#         # optional additional page numbers
#         (?:,\ ?
#     # optional label (longest to shortest):
#     (?:
#         (?:
#             (?:&\ )?note|       # note, & note
#             (?:&\ )?nn?\.?|     # n., nn., & nn.
#             (?:&\ )?fn?\.?|     # fn., & fn.
#             ¶{1,2}|             # ¶
#             §{1,2}|             # §
#             \*{1,4}|            # *
#             pg\.?|              # pg.
#             pp?\.?              # p., pp.
#         )\ ?  # optional space after label
#     )?
#     (?:
#         # page:paragraph cite, like 123:24-25 or 123:24-124:25:
#         \d+:\d+(?:-\d+(?::\d+)?)?|
#         # page range, like 12 or 12-13:
#         \d+(?:-\d+)?
#     )
# )*
#         # pin cite must be followed by one of these so it doesn't capture
#         # start of next citation
#         (?=
#             [,.;)\]\\]|  # ending punctuation
#             \ ?[(\[]|    # space and start of parens
#             $            # end of text
#         )
#     )
# ?
#             ,?\ ?
#             (?P<extra>[^(]*)
#         )
#         # content within year paren:
#         \((?:
#             # court and year:
#             (?P<court>[^)]+)\
#     (?:
#         (?P<year>
#             \d{4}
#         )
#         # Year is occasionally a range, like "1993-94" or "2005-06".
#         # For now we ignore the end of the range:
#         (?:-\d{2})?
#     )
# |
#             # just year:
#
#     (?:
#         (?P<year>
#             \d{4}
#         )
#         # Year is occasionally a range, like "1993-94" or "2005-06".
#         # For now we ignore the end of the range:
#         (?:-\d{2})?
#     )
#
#         )\)
#         # optional parenthetical comment:
#
#     (?:
#         # optional space, opening paren
#         \ ?\(
#             # capture until last end paren, we'll trim off extra afterwards
#             (?P<parenthetical>.*)
#            \)
#     )?
#
#     |  # handle a pin cite with no valid year paren:
#
#     (?P<pin_cite>
#         # optional comma, space, "at" before pin cite
#         ,?\ ?(?:at\ )?
#         # first mandatory page number
#
#     # optional label (longest to shortest):
#     (?:
#         (?:
#             (?:&\ )?note|       # note, & note
#             (?:&\ )?nn?\.?|     # n., nn., & nn.
#             (?:&\ )?fn?\.?|     # fn., & fn.
#             ¶{1,2}|             # ¶
#             §{1,2}|             # §
#             \*{1,4}|            # *
#             pg\.?|              # pg.
#             pp?\.?              # p., pp.
#         )\ ?  # optional space after label
#     )?
#     (?:
#         # page:paragraph cite, like 123:24-25 or 123:24-124:25:
#         \d+:\d+(?:-\d+(?::\d+)?)?|
#         # page range, like 12 or 12-13:
#         \d+(?:-\d+)?
#     )
#
#         # optional additional page numbers
#         (?:,\ ?
#     # optional label (longest to shortest):
#     (?:
#         (?:
#             (?:&\ )?note|       # note, & note
#             (?:&\ )?nn?\.?|     # n., nn., & nn.
#             (?:&\ )?fn?\.?|     # fn., & fn.
#             ¶{1,2}|             # ¶
#             §{1,2}|             # §
#             \*{1,4}|            # *
#             pg\.?|              # pg.
#             pp?\.?              # p., pp.
#         )\ ?  # optional space after label
#     )?
#     (?:
#         # page:paragraph cite, like 123:24-25 or 123:24-124:25:
#         \d+:\d+(?:-\d+(?::\d+)?)?|
#         # page range, like 12 or 12-13:
#         \d+(?:-\d+)?
#     )
# )*
#         # pin cite must be followed by one of these so it doesn't capture
#         # start of next citation
#         (?=
#             [,.;)\]\\]|  # ending punctuation
#             \ ?[(\[]|    # space and start of parens
#             $            # end of text
#         )
#     )
#
#     )

# %% [markdown]
# The eyecite package itself depends on a reporters_db and a courts_db package. Let's look at those.

# %%
import reporters_db

reporters_db.REPORTERS
# Out:
# {'A.': [{'cite_type': 'state_regional',
#    'editions': {'A.': {'end': datetime.datetime(1938, 12, 31, 0, 0),
#      'start': datetime.datetime(1885, 1, 1, 0, 0)},
#     'A.2d': {'end': datetime.datetime(2010, 12, 31, 0, 0),
#      'start': datetime.datetime(1938, 1, 1, 0, 0)},
#     'A.3d': {'end': None, 'start': datetime.datetime(2010, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ct;supreme.court',
#     'us:dc;court.appeals',
#     'us:de;supreme.court',
#     'us:md;court.appeals',
#     'us:me;supreme.judicial.court',
#     'us:nh;supreme.court',
#     'us:nj;supreme.court',
#     'us:pa;supreme.court',
#     'us:ri;supreme.court',
#     'us:vt;supreme.court'],
#    'name': 'Atlantic Reporter',
#    'variations': {'A. 2d': 'A.2d',
#     'A. 3d': 'A.3d',
#     'A.R.': 'A.',
#     'A.Rep.': 'A.',
#     'At.': 'A.',
#     'At. Rep.': 'A.',
#     'Atl.': 'A.',
#     'Atl. Rep.': 'A.',
#     'Atl.2d': 'A.2d',
#     'Atl.R.': 'A.'}}],
#  'A.D.': [{'cite_type': 'state',
#    'editions': {'A.D.': {'end': datetime.datetime(1955, 12, 31, 0, 0),
#      'start': datetime.datetime(1896, 1, 1, 0, 0)},
#     'A.D.2d': {'end': datetime.datetime(2004, 12, 31, 0, 0),
#      'start': datetime.datetime(1955, 1, 1, 0, 0)},
#     'A.D.3d': {'end': None, 'start': datetime.datetime(2003, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;court.appeals'],
#    'name': 'New York Supreme Court Appellate Division Reports',
#    'variations': {'A.D. 2d': 'A.D.2d',
#     'A.D. 3d': 'A.D.3d',
#     'AD 2d': 'A.D.2d',
#     'AD 3d': 'A.D.3d',
#     'Ap.': 'A.D.',
#     'Ap.2d.': 'A.D.2d',
#     'App. Div.': 'A.D.',
#     'App. Div. 2d.': 'A.D.2d',
#     'App. Div. 3d.': 'A.D.3d',
#     'App. Div. Rep.': 'A.D.',
#     'App.Div.': 'A.D.',
#     'App.Div.(N.Y.)': 'A.D.',
#     'App.Div.2d.': 'A.D.2d',
#     'App.Div.3d.': 'A.D.3d',
#     'N.Y.App.Dec.': 'A.D.',
#     'N.Y.App.Div.': 'A.D.'}}],
#  'A.E.C.': [{'cite_type': 'federal',
#    'editions': {'A.E.C.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'href': 'https://law.resource.org/pub/us/code/blue/IndigoBook.html#T2',
#    'mlz_jurisdiction': ['us;federal'],
#    'name': 'Atomic Energy Commission Reports',
#    'variations': {}}],
#  'A.F.T.R. (P-H)': [{'cite_type': 'specialty',
#    'editions': {'A.F.T.R. (P-H)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;tax.court'],
#    'name': 'American Federal Tax Reports',
#    'variations': {}}],
#  'A.F.T.R. (RIA)': [{'cite_type': 'specialty',
#    'editions': {'A.F.T.R. (RIA)': {'end': datetime.datetime(1957, 12, 31, 0, 0),
#      'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'A.F.T.R.2d (RIA)': {'end': None,
#      'start': datetime.datetime(1958, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;tax.court'],
#    'name': 'American Federal Tax Reports',
#    'notes': 'See: https://www.irs.gov/pub/irs-tege/eotopich87.pdf',
#    'variations': {'A.F.T.R.': 'A.F.T.R. (RIA)',
#     'A.F.T.R. 2d': 'A.F.T.R.2d (RIA)',
#     'A.F.T.R. 2d (RIA)': 'A.F.T.R.2d (RIA)',
#     'A.F.T.R.2d': 'A.F.T.R.2d (RIA)',
#     'P-H T.C. Memo.': 'A.F.T.R. (RIA)'}}],
#  'A.K. Marsh.': [{'cite_type': 'state',
#    'editions': {'A.K. Marsh.': {'end': datetime.datetime(1821, 12, 31, 0, 0),
#      'start': datetime.datetime(1817, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ky;supreme.court'],
#    'name': 'Kentucky Reports, Marshall, A.K.',
#    'variations': {'Ky.(A.K.Marsh.)': 'A.K. Marsh.',
#     'Mar.': 'A.K. Marsh.',
#     'Mar. Rep.': 'A.K. Marsh.',
#     'Marsh.': 'A.K. Marsh.',
#     'Marsh. Rep.': 'A.K. Marsh.',
#     'Marsh.(Ky.)': 'A.K. Marsh.',
#     'Marsh.A.K.': 'A.K. Marsh.'}}],
#  'A.L.R.': [{'cite_type': 'specialty',
#    'editions': {'A.L.R.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'A.L.R. 2d': {'end': None, 'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'A.L.R. 3d': {'end': None, 'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'A.L.R. 4th': {'end': None, 'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'A.L.R. 5th': {'end': None, 'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'A.L.R. 6th': {'end': None, 'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'href': 'http://legalsolutions.thomsonreuters.com/law-products/westlaw-legal-research/litigator/alr',
#    'mlz_jurisdiction': [],
#    'name': 'American Law Reports',
#    'publisher': 'Thompson Reuters',
#    'variations': {'A.L.R.2d': 'A.L.R. 2d',
#     'A.L.R.3d': 'A.L.R. 3d',
#     'A.L.R.4th': 'A.L.R. 4th',
#     'A.L.R.5th': 'A.L.R. 5th',
#     'A.L.R.6th': 'A.L.R. 6th',
#     'ALR': 'A.L.R.',
#     'ALR 2d': 'A.L.R. 2d',
#     'ALR 3d': 'A.L.R. 3d',
#     'ALR 4th': 'A.L.R. 4th',
#     'ALR 5th': 'A.L.R. 5th',
#     'ALR 6th': 'A.L.R. 6th'}}],
#  'A.L.R. Fed.': [{'cite_type': 'federal',
#    'editions': {'A.L.R. Fed.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'A.L.R. Fed. 2d': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'American Law Reports Annotated, Federal',
#    'variations': {'A.L.R. Fed.2d': 'A.L.R. Fed. 2d'}}],
#  'A.M.C.': [{'cite_type': 'specialty',
#    'editions': {'A.M.C.': {'end': None,
#      'start': datetime.datetime(1923, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'American Maritime Cases',
#    'variations': {'AMC': 'A.M.C.'}}],
#  'AWCC': [{'cite_type': 'neutral',
#    'editions': {'AWCC': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'href': 'http://www.awcc.state.ar.us/index.html',
#    'mlz_jurisdiction': [],
#    'name': 'Arkansas Neutral Citation (Workers Compensation Commission',
#    'notes': 'The commission has no rule to use these citations, but the Arksansas reporter generates the citations anyway, and they wind up in Lexis that way.',
#    'variations': {}}],
#  'AZ': [{'cite_type': 'neutral',
#    'editions': {'AZ': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:az;supreme.court'],
#    'name': 'Arizona Neutral Citation',
#    'variations': {}}],
#  'Abb.': [{'cite_type': 'federal',
#    'editions': {'Abb.': {'end': datetime.datetime(1871, 12, 31, 0, 0),
#      'start': datetime.datetime(1863, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Abbott, United States Circuit and District Court Reports',
#    'variations': {'Abb': 'Abb.', 'Abb. Rep.': 'Abb.'}}],
#  'Abb. Adm.': [{'cite_type': 'specialty',
#    'editions': {'Abb. Adm.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': "Abbott's Admiralty Reports",
#    'variations': {}}],
#  'Abb. Ct. App.': [{'cite_type': 'state',
#    'editions': {'Abb. Ct. App.': {'end': datetime.datetime(1869, 12, 31, 0, 0),
#      'start': datetime.datetime(1807, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;court.appeals'],
#    'name': "Abbott's Court of Appeals Decisions",
#    'variations': {'Abb. Ct. App. Dec.': 'Abb. Ct. App.'}}],
#  'Abb. N. Cas.': [{'cite_type': 'state',
#    'editions': {'Abb. N. Cas.': {'end': datetime.datetime(1894, 12, 31, 0, 0),
#      'start': datetime.datetime(1876, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;court.appeals'],
#    'name': "Abbott's New Cases",
#    'variations': {'A.N.': 'Abb. N. Cas.',
#     'A.N.C.': 'Abb. N. Cas.',
#     'Abb.N. Cas.': 'Abb. N. Cas.',
#     'Abb.N.C.': 'Abb. N. Cas.'}}],
#  'Abb. Pr.': [{'cite_type': 'state',
#    'editions': {'Abb. Pr.': {'end': datetime.datetime(1865, 12, 31, 0, 0),
#      'start': datetime.datetime(1854, 1, 1, 0, 0)},
#     'Abb. Pr. (n.s.)': {'end': datetime.datetime(1875, 12, 31, 0, 0),
#      'start': datetime.datetime(1863, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;court.appeals'],
#    'name': "Abbott's Practice Reports",
#    'variations': {'Abb.P.R.': 'Abb. Pr.',
#     'Abb.Pr.Rep.': 'Abb. Pr.',
#     'Abb.Prac.': 'Abb. Pr.',
#     'Abbott P.R.': 'Abb. Pr.',
#     'Abbott Pr.Rep.': 'Abb. Pr.',
#     'Abbott Pract.Cas.': 'Abb. Pr.',
#     "Abbott's Pr.Rep.": 'Abb. Pr.',
#     "Abbott's Prac.Rep.": 'Abb. Pr.'}}],
#  'Accom. Disabilities Dec. (CCH)': [{'cite_type': 'specialty',
#    'editions': {'Accom. Disabilities Dec. (CCH)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'CCH Accommodating Disabilities Decisions',
#    'variations': {}}],
#  'Add.': [{'cite_format': '{reporter} {page}',
#    'cite_type': 'state',
#    'editions': {'Add.': {'end': datetime.datetime(1799, 12, 31, 0, 0),
#      'start': datetime.datetime(1791, 1, 1, 0, 0)}},
#    'examples': ['Graham v. Goudy, Add. 55'],
#    'mlz_jurisdiction': ['us:pa;supreme.court', 'us:pa;superior.court'],
#    'name': 'Reports of cases of the State of Pennsylvania by Alexander Addison',
#    'notes': 'Single volume, typically cited without volume number',
#    'variations': {}}],
#  'Adv. S.': [{'cite_type': 'state',
#    'editions': {'Adv. S.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ms;supreme.court'],
#    'name': 'Mississippi Reporter Advance Sheets',
#    'notes': "After making several calls to libraries in Mississippi, it seems nobody knows what this reporter is or was. It seems to have been popular in the 50's, and appears to be the advance sheets for the Mississippi Reports. After speaking with one diligent librarian, we discovered that the physical volumes of the Mississippi Reporter listed these citations as alternate citations, but that the Southern Reporter did not. This aligns with results that we find in CourtListener, which seem to skew strongly towards cases only in Mississippi. The fact that no library in Mississippi seems to have this reporter also indicates that it only contained Advance Sheets, but what's strange is, why bother making a real reporter if your advance sheets are organized enough to have citations and everything, as opposed to the norm of having monthly or weekly editions. Strange stuff, this.",
#    'publisher': 'Mississippi Reporter Company',
#    'variations': {'Adv.S.': 'Adv. S.'}}],
#  'Agric. Dec': [{'cite_type': 'federal',
#    'editions': {'Agric. Dec': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'examples': ['55 Agric Dec. 1121'],
#    'href': 'https://law.resource.org/pub/us/code/blue/IndigoBook.html#T2',
#    'mlz_jurisdiction': ['us;federal'],
#    'name': 'Agriculture Decisions',
#    'variations': {}}],
#  'Aik.': [{'cite_type': 'state',
#    'editions': {'Aik.': {'end': datetime.datetime(1828, 12, 31, 0, 0),
#      'start': datetime.datetime(1825, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:vt;supreme.court'],
#    'name': 'Vermont Reports, Aikens',
#    'variations': {'Aik. Rep.': 'Aik.'}}],
#  'Ala.': [{'cite_type': 'state',
#    'editions': {'Ala.': {'end': datetime.datetime(1976, 12, 31, 0, 0),
#      'start': datetime.datetime(1840, 1, 1, 0, 0)},
#     'Ala. 2d': {'end': None, 'start': datetime.datetime(1977, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:al;supreme.court'],
#    'name': 'Alabama Reports',
#    'variations': {'Ala. Rep.': 'Ala.'}}],
#  'Ala. App.': [{'cite_type': 'state',
#    'editions': {'Ala. App.': {'end': datetime.datetime(1976, 12, 31, 0, 0),
#      'start': datetime.datetime(1910, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:al;supreme.court'],
#    'name': 'Alabama Appellate Courts Reports',
#    'variations': {'Ala.App.': 'Ala. App.'}}],
#  'Ala. App. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ala. App. LEXIS': {'end': datetime.datetime(1969, 12, 31, 0, 0),
#      'start': datetime.datetime(1911, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:al;appeals.court'],
#    'name': 'LexisNexis Alabama Appeals Court',
#    'variations': {}}],
#  'Ala. Civ. App. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ala. Civ. App. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:al;civil.appeals.court'],
#    'name': 'LexisNexis Alabama Court of Civil Appeals',
#    'variations': {}}],
#  'Ala. Crim. App. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ala. Crim. App. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:al;criminal.appeals.court'],
#    'name': 'LexisNexis Alabama Court of Criminal Appeals',
#    'variations': {}}],
#  'Ala. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ala. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:al;supreme.court'],
#    'name': 'LexisNexis Alabama Supreme Court',
#    'variations': {}}],
#  'Alas. App. LEXIS': [{'cite_type': 'state',
#    'editions': {'Alas. App. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ak;appeals.court'],
#    'name': 'LexisNexis Alaska Appeals Court',
#    'variations': {}}],
#  'Alas. LEXIS': [{'cite_type': 'state',
#    'editions': {'Alas. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ak;supreme.court'],
#    'name': 'LexisNexis Alaska Supreme Court',
#    'variations': {}}],
#  'Alaska': [{'cite_type': 'state',
#    'editions': {'Alaska': {'end': datetime.datetime(1959, 12, 31, 0, 0),
#      'start': datetime.datetime(1884, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ak;supreme.court'],
#    'name': 'Alaska Reports',
#    'variations': {'Alk.': 'Alaska'}}],
#  'Alaska Fed.': [{'cite_type': 'state',
#    'editions': {'Alaska Fed.': {'end': datetime.datetime(1937, 12, 31, 0, 0),
#      'start': datetime.datetime(1869, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ak;supreme.court'],
#    'name': 'Alaska Federal Reports',
#    'variations': {'A.F.Rep.': 'Alaska Fed.',
#     'Alaska Fed.R.': 'Alaska Fed.',
#     'Alaska Fed.Rep.': 'Alaska Fed.'}}],
#  'Alb. Law J.': [{'cite_type': 'specialty',
#    'editions': {'Alb. Law J.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Albany Law Journal',
#    'variations': {}}],
#  'Allen': [{'cite_type': 'state',
#    'editions': {'Allen': {'end': datetime.datetime(1867, 12, 31, 0, 0),
#      'start': datetime.datetime(1861, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ma;appeals.court'],
#    'name': 'Massachusetts Reports, Allen',
#    'variations': {'All.': 'Allen',
#     'All. Rep.': 'Allen',
#     'Mass.(Allen)': 'Allen'}}],
#  'Am. Ann. Cas.': [{'cite_type': 'state_regional',
#    'editions': {'Am. Ann. Cas.': {'end': datetime.datetime(1912, 12, 31, 0, 0),
#      'start': datetime.datetime(1904, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:oh;supreme.court',
#     'us:in;supreme.court',
#     'us:ny;court.appeals'],
#    'name': 'American Annotated Cases',
#    'notes': 'More jurisdictions are likely to be found.',
#    'variations': {'Am.Ann.Cas.': 'Am. Ann. Cas.'}}],
#  'Am. B.R.': [{'cite_type': 'specialty',
#    'editions': {'Am. B.R.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'Am. B.R. (N.S.)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'American Bankruptcy Reports',
#    'variations': {'Am. B.R. (n.s.)': 'Am. B.R. (N.S.)'}}],
#  'Am. Dec.': [{'cite_type': 'federal',
#    'editions': {'Am. Dec.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'American Decisions',
#    'variations': {'Am. D.': 'Am. Dec.', "Am. Dec's.": 'Am. Dec.'}}],
#  'Am. Disabilities Cas. (BNA)': [{'cite_type': 'specialty',
#    'editions': {'Am. Disabilities Cas. (BNA)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Americans with Disabilities Cases (BNA)',
#    'variations': {}}],
#  'Am. Disabilities Dec.': [{'cite_type': 'specialty',
#    'editions': {'Am. Disabilities Dec.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Americans with Disabilities Decisions',
#    'variations': {}}],
#  'Am. Law Reg.': [{'cite_type': 'state',
#    'editions': {'Am. Law Reg.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'Am. Law Reg. (N.S.)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:pa;supreme.court'],
#    'name': 'American Law Register',
#    'variations': {'Am. L. Reg., n.s.': 'Am. Law Reg. (N.S.)'}}],
#  'Am. Law T. Rep. Bankr.': [{'cite_type': 'specialty',
#    'editions': {'Am. Law T. Rep. Bankr.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'American Law Times, Bankruptcy Reports, United States (US) Courts',
#    'variations': {'A.L.T. Bankr.': 'Am. Law T. Rep. Bankr.'}}],
#  'Am. Law T. Rep. U.S. Cts.': [{'cite_type': 'federal',
#    'editions': {'Am. Law T. Rep. U.S. Cts.': {'end': datetime.datetime(1874, 12, 31, 0, 0),
#      'start': datetime.datetime(1868, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'American Law Times Reports, United States (US) Courts',
#    'variations': {}}],
#  'Am. Law. Rec.': [{'cite_type': 'federal',
#    'editions': {'Am. Law. Rec.': {'end': datetime.datetime(1887, 12, 31, 0, 0),
#      'start': datetime.datetime(1872, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'American Law Record',
#    'publisher': 'Bloch & Co',
#    'variations': {'Am. Law Rec.': 'Am. Law. Rec.'}}],
#  'Am. Lead. Cas.': [{'cite_type': 'federal',
#    'editions': {'Am. Lead. Cas.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'American Leading Cases',
#    'variations': {'Am. L. C.': 'Am. Lead. Cas.',
#     'Am. L. Cas': 'Am. Lead. Cas.',
#     'Am. Leading Cas': 'Am. Lead. Cas.',
#     'American Leading Cases': 'Am. Lead. Cas.',
#     'American Leading Cases (U.S.)': 'Am. Lead. Cas.'}}],
#  'Am. Neg. Ca.': [{'cite_type': 'state',
#    'editions': {'Am. Neg. Ca.': {'end': datetime.datetime(1897, 12, 31, 0, 0),
#      'start': datetime.datetime(1789, 1, 1, 0, 0)},
#     'Am. Neg. Cas.': {'end': datetime.datetime(1907, 12, 31, 0, 0),
#      'start': datetime.datetime(1789, 1, 1, 0, 0)},
#     'Am. Neg. Cases': {'end': datetime.datetime(1987, 12, 31, 0, 0),
#      'start': datetime.datetime(1789, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;court.appeals'],
#    'name': 'American Negligence Cases',
#    'notes': 'Date estimates',
#    'variations': {'Am. Negl. Cas.': 'Am. Neg. Ca.',
#     'Am.Negl.Cas.': 'Am. Neg. Cases'}}],
#  'Am. Rep.': [{'cite_type': 'state_regional',
#    'editions': {'Am. Rep.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ma;supreme.court'],
#    'name': 'American Reports',
#    'variations': {'Am. Reports': 'Am. Rep.', 'Am.Rep.': 'Am. Rep.'}}],
#  'Am. Samoa': [{'cite_type': 'state',
#    'editions': {'Am. Samoa': {'end': datetime.datetime(1975, 12, 31, 0, 0),
#      'start': datetime.datetime(1900, 1, 1, 0, 0)},
#     'Am. Samoa 2d': {'end': datetime.datetime(1999, 12, 31, 0, 0),
#      'start': datetime.datetime(1978, 1, 1, 0, 0)},
#     'Am. Samoa 3d': {'end': None,
#      'start': datetime.datetime(1993, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:as;high.court'],
#    'name': 'American Samoa Reports',
#    'variations': {}}],
#  'Am. St. Rep.': [{'cite_type': 'state',
#    'editions': {'Am. St. Rep.': {'end': None,
#      'start': datetime.datetime(1888, 1, 1, 0, 0)}},
#    'href': 'https://catalog.hathitrust.org/Record/006692328',
#    'mlz_jurisdiction': [],
#    'name': 'American State Reports',
#    'notes': 'Abbreviations from Cardiff Index to Legal Abbreviations. Start date from v1 of scanned volume',
#    'variations': {'Am. S. R.': 'Am. St. Rep.',
#     'Am. St. R.': 'Am. St. Rep.',
#     'Am.S.R.': 'Am. St. Rep.',
#     'Am.St.R.': 'Am. St. Rep.',
#     'Am.St.Rep.': 'Am. St. Rep.'}}],
#  'Am. Tribal Law': [{'cite_type': 'state',
#    'editions': {'Am. Tribal Law': {'end': None,
#      'start': datetime.datetime(1997, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': "West's American Tribal Law Reporter",
#    'variations': {}}],
#  'Amer. L. Rev.': [{'cite_type': 'federal',
#    'editions': {'Amer. L. Rev.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c2:ny.nd;district.court'],
#    'name': 'American Law Review',
#    'variations': {}}],
#  'Ant. N.P. Cas.': [{'cite_type': 'state',
#    'editions': {'Ant. N.P. Cas.': {'end': datetime.datetime(1851, 12, 31, 0, 0),
#      'start': datetime.datetime(1807, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;court.appeals'],
#    'name': "Anthon's Nisi Prius Cases",
#    'variations': {'Anth.': 'Ant. N.P. Cas.',
#     'Anthon N.P.(N.Y.)': 'Ant. N.P. Cas.'}}],
#  'App. D.C.': [{'cite_type': 'state',
#    'editions': {'App. D.C.': {'end': datetime.datetime(1941, 12, 31, 0, 0),
#      'start': datetime.datetime(1893, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:dc;court.appeals'],
#    'name': 'Appeal Cases, District of Columbia',
#    'variations': {}}],
#  'Ariz.': [{'cite_type': 'state',
#    'editions': {'Ariz.': {'end': None,
#      'start': datetime.datetime(1866, 1, 1, 0, 0)}},
#    'href': 'http://legalsolutions.thomsonreuters.com/law-products/Case-Law/Arizona-Reports/p/100005739',
#    'mlz_jurisdiction': ['us:az;supreme.court'],
#    'name': 'Arizona Reporter',
#    'variations': {}}],
#  'Ariz. Adv. Rep.': [{'cite_type': 'state',
#    'editions': {'Ariz. Adv. Rep.': {'end': None,
#      'start': datetime.datetime(1987, 1, 1, 0, 0)}},
#    'href': 'http://www.code-co.com/',
#    'mlz_jurisdiction': [],
#    'name': 'Arizona Advance Reports',
#    'notes': 'Appears to be a very small publisher. Only publishes this and Utah Advance Reports. Date confirmed via phone call.',
#    'publisher': 'Code Co.',
#    'variations': {}}],
#  'Ariz. App.': [{'cite_type': 'state',
#    'editions': {'Ariz. App.': {'end': datetime.datetime(1976, 12, 31, 0, 0),
#      'start': datetime.datetime(1965, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:az;supreme.court'],
#    'name': 'Arizona Appeals Reports',
#    'variations': {'Ariz.App.': 'Ariz. App.'}}],
#  'Ariz. App. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ariz. App. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:az;appeals.court'],
#    'name': 'LexisNexis Arizona Court of Appeals',
#    'variations': {}}],
#  'Ariz. App. Unpub. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ariz. App. Unpub. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:az;appeals.court'],
#    'name': 'LexisNexis Arizona Appeals Court Unpublished',
#    'variations': {}}],
#  'Ariz. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ariz. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:az;supreme.court'],
#    'name': 'LexisNexis Arizona Supreme Court',
#    'variations': {}}],
#  'Ariz. Tax LEXIS': [{'cite_type': 'state',
#    'editions': {'Ariz. Tax LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:az;supreme.court'],
#    'name': 'LexisNexis Arizona Supreme Court',
#    'variations': {}}],
#  'Ariz. Unpub. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ariz. Unpub. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:az;supreme.court'],
#    'name': 'LexisNexis Arizona Supreme Court Unpublished',
#    'variations': {}}],
#  'Ark.': [{'cite_type': 'state',
#    'editions': {'Ark.': {'end': None,
#      'start': datetime.datetime(1837, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ar;supreme.court'],
#    'name': 'Arkansas Reports',
#    'variations': {'ARK.': 'Ark.',
#     'Ak.': 'Ark.',
#     'Ark': 'Ark.',
#     'Ark. Rep.': 'Ark.'}}],
#  'Ark. Adv. Op.': [{'cite_type': 'state',
#    'editions': {'Ark. Adv. Op.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ar;supreme.court'],
#    'name': 'Arkansas (AR) Advanced Opinions',
#    'variations': {}}],
#  "Ark. App'x": [{'cite_type': 'state',
#    'editions': {"Ark. App'x": {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ar;supreme.court'],
#    'name': 'Arkansas Appendix',
#    'variations': {'Ark. Appx.': "Ark. App'x"}}],
#  'Ark. App.': [{'cite_type': 'state',
#    'editions': {'Ark. App.': {'end': None,
#      'start': datetime.datetime(1981, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ar;supreme.court'],
#    'name': 'Arkansas Appellate Reports',
#    'variations': {'Ak. App.': 'Ark. App.'}}],
#  'Ark. App. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ark. App. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ar;superior.court'],
#    'name': 'LexisNexis Arkansas Court of Appeals',
#    'variations': {}}],
#  'Ark. LEXIS': [{'cite_type': 'state',
#    'editions': {'Ark. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ar;supreme.court'],
#    'name': 'LexisNexis Arkansas Supreme Court',
#    'variations': {}}],
#  'Auto. Cas.': [{'cite_type': 'specialty',
#    'editions': {'Auto. Cas.': {'end': None,
#      'start': datetime.datetime(1895, 1, 1, 0, 0)},
#     'Auto. Cas.2d': {'end': None,
#      'start': datetime.datetime(1895, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Automobile Cases (CCH)',
#    'variations': {'Auto. Cas. (CCH)': 'Auto. Cas.',
#     'Auto. Cas. 2d': 'Auto. Cas.2d',
#     'Auto. Cas. 2d (CCH)': 'Auto. Cas.2d'}}],
#  'Av. Cas. (CCH)': [{'cite_type': 'specialty',
#    'editions': {'Av. Cas. (CCH)': {'end': None,
#      'start': datetime.datetime(1903, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Aviation Cases (CCH)',
#    'notes': 'Aviation didnt start until 1903 in the United States.',
#    'variations': {'Av. Cas.': 'Av. Cas. (CCH)'}}],
#  'B. Mon.': [{'cite_type': 'state',
#    'editions': {'B. Mon.': {'end': datetime.datetime(1857, 12, 31, 0, 0),
#      'start': datetime.datetime(1840, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ky;supreme.court'],
#    'name': 'Kentucky Reports, Monroe, Ben',
#    'variations': {'B. Mon. Rep.': 'B. Mon.',
#     'Ky.(B.Mon.)': 'B. Mon.',
#     'Mon.': 'B. Mon.',
#     'Mon. Rep.': 'B. Mon.',
#     'Mon.B.': 'B. Mon.',
#     'Monroe, B.': 'B. Mon.'}}],
#  'B.C.A. (CCH)': [{'cite_type': 'specialty',
#    'editions': {'B.C.A. (CCH)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Board of Contract Appeals Decisions',
#    'variations': {}}],
#  'B.R.': [{'cite_type': 'specialty',
#    'editions': {'B.R.': {'end': None,
#      'start': datetime.datetime(1979, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c0:dc.d;bankruptcy.court',
#     'us:c10:co.d;bankruptcy.court',
#     'us:c10:ks.d;bankruptcy.court',
#     'us:c10:nm.d;bankruptcy.court',
#     'us:c10:ok.ed;bankruptcy.court',
#     'us:c10:ok.nd;bankruptcy.court',
#     'us:c10:ok.wd;bankruptcy.court',
#     'us:c10:ut.d;bankruptcy.court',
#     'us:c10:wy.d;bankruptcy.court',
#     'us:c10;bankruptcy.appellate.panel',
#     'us:c11:al.md;bankruptcy.court',
#     'us:c11:al.nd;bankruptcy.court',
#     'us:c11:al.sd;bankruptcy.court',
#     'us:c11:fl.md;bankruptcy.court',
#     'us:c11:fl.nd;bankruptcy.court',
#     'us:c11:fl.sd;bankruptcy.court',
#     'us:c11:ga.md;bankruptcy.court',
#     'us:c11:ga.nd;bankruptcy.court',
#     'us:c11:ga.sd;bankruptcy.court',
#     'us:c1:ma.d;bankruptcy.court',
#     'us:c1:me.d;bankruptcy.appellate.panel',
#     'us:c1:me.d;bankruptcy.court',
#     'us:c1:nh.d;bankruptcy.court',
#     'us:c1:pr.d;bankruptcy.court',
#     'us:c1:ri.d;bankruptcy.court',
#     'us:c1;bankruptcy.appellate.panel',
#     'us:c2:ct.d;bankruptcy.court',
#     'us:c2:ny.ed;bankruptcy.court',
#     'us:c2:ny.nd;bankruptcy.court',
#     'us:c2:ny.sd;bankruptcy.court',
#     'us:c2:ny.wd;bankruptcy.court',
#     'us:c2:vt.d;bankruptcy.court',
#     'us:c2;bankruptcy.appellate.panel',
#     'us:c3:de.d;bankruptcy.court',
#     'us:c3:nj.d;bankruptcy.court',
#     'us:c3:pa.ed;bankruptcy.court',
#     'us:c3:pa.md;bankruptcy.court',
#     'us:c3:pa.wd;bankruptcy.court',
#     'us:c3:vi.d;bankruptcy.court',
#     'us:c4:md.d;bankruptcy.court',
#     'us:c4:nc.ed;bankruptcy.court',
#     'us:c4:nc.md;bankruptcy.court',
#     'us:c4:nc.wd;bankruptcy.court',
#     'us:c4:sc.d;bankruptcy.court',
#     'us:c4:va.ed;bankruptcy.court',
#     'us:c4:va.wd;bankruptcy.court',
#     'us:c4:wv.nd;bankruptcy.court',
#     'us:c4:wv.sd;bankruptcy.court',
#     'us:c5:la.ed;bankruptcy.court',
#     'us:c5:la.md;bankruptcy.court',
#     'us:c5:la.wd;bankruptcy.court',
#     'us:c5:ms.nd;bankruptcy.court',
#     'us:c5:ms.sd;bankruptcy.court',
#     'us:c5:tx.ed;bankruptcy.court',
#     'us:c5:tx.nd;bankruptcy.court',
#     'us:c5:tx.sd;bankruptcy.court',
#     'us:c5:tx.wd;bankruptcy.court',
#     'us:c6:ky.ed;bankruptcy.court',
#     'us:c6:ky.wd;bankruptcy.court',
#     'us:c6:mi.ed;bankruptcy.court',
#     'us:c6:mi.wd;bankruptcy.court',
#     'us:c6:oh.nd;bankruptcy.court',
#     'us:c6:oh.sd;bankruptcy.court',
#     'us:c6:tn.d;bankruptcy.court',
#     'us:c6:tn.ed;bankruptcy.court',
#     'us:c6:tn.md;bankruptcy.court',
#     'us:c6:tn.wd;bankruptcy.court',
#     'us:c6;bankruptcy.appellate.panel',
#     'us:c7:il.cd;bankruptcy.court',
#     'us:c7:il.nd;bankruptcy.court',
#     'us:c7:il.sd;bankruptcy.court',
#     'us:c7:in.nd;bankruptcy.court',
#     'us:c7:in.sd;bankruptcy.court',
#     'us:c7:wi.ed;bankruptcy.court',
#     'us:c7:wi.wd;bankruptcy.court',
#     'us:c8:ar.ed;bankruptcy.court',
#     'us:c8:ar.wd;bankruptcy.court',
#     'us:c8:ia.nd;bankruptcy.court',
#     'us:c8:ia.sd;bankruptcy.court',
#     'us:c8:mn.d;bankruptcy.court',
#     'us:c8:mo.ed;bankruptcy.court',
#     'us:c8:mo.wd;bankruptcy.court',
#     'us:c8:nd.d;bankruptcy.court',
#     'us:c8:ne.d;bankruptcy.court',
#     'us:c8:sd.d;bankruptcy.court',
#     'us:c8;bankruptcy.appellate.panel',
#     'us:c9:ak.d;bankruptcy.court',
#     'us:c9:az.d;bankruptcy.court',
#     'us:c9:ca.cd;bankruptcy.court',
#     'us:c9:ca.ed;bankruptcy.court',
#     'us:c9:ca.nd;bankruptcy.court',
#     'us:c9:ca.sd;bankruptcy.court',
#     'us:c9:gu.d;bankruptcy.court',
#     'us:c9:hi.d;bankruptcy.court',
#     'us:c9:id.d;bankruptcy.court',
#     'us:c9:mp.d;bankruptcy.court',
#     'us:c9:mt.d;bankruptcy.court',
#     'us:c9:nv.d;bankruptcy.court',
#     'us:c9:or.d;bankruptcy.court',
#     'us:c9:wa.ed;bankruptcy.court',
#     'us:c9:wa.wd;bankruptcy.court',
#     'us:c9;bankruptcy.appellate.panel'],
#    'name': 'Bankruptcy Reporter',
#    'variations': {'B. R.': 'B.R.', 'BR': 'B.R.'}}],
#  'B.T.A.': [{'cite_type': 'specialty',
#    'editions': {'B.T.A.': {'end': datetime.datetime(1942, 12, 31, 0, 0),
#      'start': datetime.datetime(1924, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;tax.court'],
#    'name': 'Reports of the United States Board of Tax Appeals',
#    'variations': {}}],
#  'B.T.A.M. (P-H)': [{'cite_type': 'specialty',
#    'editions': {'B.T.A.M. (P-H)': {'end': datetime.datetime(1942, 12, 31, 0, 0),
#      'start': datetime.datetime(1928, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;tax.court'],
#    'name': 'Board of Tax Appeals Memorandum Decisions',
#    'variations': {}}],
#  'BCA': [{'cite_type': 'federal',
#    'editions': {'BCA': {'end': None,
#      'regexes': ['$full_cite_cch'],
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'examples': ['93-1 BCA ¶ 25,508'],
#    'href': 'https://law.resource.org/pub/us/code/blue/IndigoBook.html#T2',
#    'mlz_jurisdiction': ['us;federal'],
#    'name': 'Board of Contract Appeals Decisions, published by Commerce Clearing House',
#    'variations': {}}],
#  'BNA OSHC': [{'cite_type': 'specialty',
#    'editions': {'BNA OSHC': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'href': 'http://www.bna.com/occupational-safety--p4900/',
#    'mlz_jurisdiction': [],
#    'name': 'Occupational Safety & Health Cases',
#    'notes': 'See https://law.resource.org/pub/us/code/blue/IndigoBook.html#T2 for nonstandard abbreviation',
#    'variations': {'O.S.H. Cas.': 'BNA OSHC',
#     'O.S.H. Cas. (BNA)': 'BNA OSHC',
#     'O.S.H. Cases': 'BNA OSHC',
#     'O.S.H. Cases (BNA)': 'BNA OSHC'}}],
#  'BTA LEXIS': [{'cite_type': 'specialty_lexis',
#    'editions': {'BTA LEXIS': {'end': datetime.datetime(1942, 12, 31, 0, 0),
#      'start': datetime.datetime(1928, 1, 1, 0, 0)}},
#    'examples': ['1928 BTA LEXIS 3389'],
#    'mlz_jurisdiction': ['us:c;tax.court'],
#    'name': 'Board of Tax Appeals Lexis',
#    'variations': {}}],
#  'Backes': [{'cite_type': 'state',
#    'editions': {'Backes': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:nj;supreme.court'],
#    'name': "Backes' Reporter",
#    'variations': {}}],
#  'Bail.': [{'cite_type': 'state',
#    'editions': {'Bail.': {'end': datetime.datetime(1832, 12, 31, 0, 0),
#      'start': datetime.datetime(1828, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:sc;supreme.court'],
#    'name': 'South Carolina Reports, Bailey',
#    'variations': {'Bai.': 'Bail.',
#     'Bail. Rep.': 'Bail.',
#     'Bail.L.': 'Bail.',
#     'Bail.L.(S.C.)': 'Bail.',
#     'Bailey': 'Bail.',
#     'Bailey Rep.': 'Bail.',
#     'S.C.L.(Bail.)': 'Bail.'}}],
#  'Bail. Eq.': [{'cite_type': 'state',
#    'editions': {'Bail. Eq.': {'end': datetime.datetime(1831, 12, 31, 0, 0),
#      'start': datetime.datetime(1830, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:sc;supreme.court'],
#    'name': "South Carolina Reports, Bailey's Equity",
#    'variations': {'Bai.Eq.': 'Bail. Eq.',
#     'Bail.Eq.(S.C.)': 'Bail. Eq.',
#     'Bailey': 'Bail. Eq.',
#     'Bailey Ch.': 'Bail. Eq.',
#     'Bailey Eq.': 'Bail. Eq.',
#     'Bailey Rep.': 'Bail. Eq.',
#     'S.C.Eq.(Bail.Eq.)': 'Bail. Eq.'}}],
#  'Baldw.': [{'cite_type': 'federal',
#    'editions': {'Baldw.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'examples': ['Baldw. 196'],
#    'mlz_jurisdiction': [],
#    'name': "Baldwin's United States Circuit Court Reports",
#    'notes': 'Reporter does not appear to have a volume as part of citation',
#    'variations': {'Bald': 'Baldw.',
#     'Bald. C.C.': 'Baldw.',
#     'Baldw': 'Baldw.',
#     "Baldwin's C.C. U.S. Rep": 'Baldw.',
#     "Baldwin's Rep.": 'Baldw.'}}],
#  'Ban. & A.': [{'cite_type': 'specialty',
#    'editions': {'Ban. & A.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;court.customs.patent.appeals'],
#    'name': "Banning & Arden's Patent Reports (US)",
#    'variations': {}}],
#  'Banking Rep. (BNA)': [{'cite_type': 'specialty',
#    'editions': {'Banking Rep. (BNA)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': "BNA's Banking Report",
#    'variations': {}}],
#  'Bankr. Ct. Dec. (CRR)': [{'cite_type': 'specialty',
#    'editions': {'Bankr. Ct. Dec. (CRR)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Bankruptcy Court Decisions',
#    'variations': {'B.C.D.': 'Bankr. Ct. Dec. (CRR)',
#     'Bankr. Ct. Dec.': 'Bankr. Ct. Dec. (CRR)',
#     'Bankr.Ct.Dec.': 'Bankr. Ct. Dec. (CRR)'}}],
#  'Bankr. Ct. Dec. (LRP)': [{'cite_type': 'specialty',
#    'editions': {'Bankr. Ct. Dec. (LRP)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Bankruptcy Court Decisions',
#    'variations': {}}],
#  'Bankr. Ct. Rep.': [{'cite_type': 'specialty',
#    'editions': {'Bankr. Ct. Rep.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Bankruptcy Court Reporter',
#    'variations': {}}],
#  'Bankr. L. Rep.': [{'cite_format': '{reporter} {page}',
#    'cite_type': 'specialty',
#    'editions': {'Bankr. L. Rep.': {'end': None,
#      'regexes': ['$full_cite_cch'],
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'examples': ['Bankr. L. Rep. P12,345',
#     'Bankr. L. Rep. P 80679',
#     'Bankr. L. Rep. (CCH) ¶ 67,488',
#     'Bankr. L. Rep. (C.C.H.) ¶67,049'],
#    'mlz_jurisdiction': [],
#    'name': 'Bankruptcy Law Reporter',
#    'variations': {'Bankr. L. Rep. (C.C.H.)': 'Bankr. L. Rep.',
#     'Bankr. L. Rep. (CCH)': 'Bankr. L. Rep.'}}],
#  'Bankr. LEXIS': [{'cite_type': 'specialty',
#    'editions': {'Bankr. LEXIS': {'end': None,
#      'start': datetime.datetime(1979, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c0:dc.d;bankruptcy.court',
#     'us:c10:co.d;bankruptcy.court',
#     'us:c10:ks.d;bankruptcy.court',
#     'us:c10:nm.d;bankruptcy.court',
#     'us:c10:ok.ed;bankruptcy.court',
#     'us:c10:ok.nd;bankruptcy.court',
#     'us:c10:ok.wd;bankruptcy.court',
#     'us:c10:ut.d;bankruptcy.court',
#     'us:c10:wy.d;bankruptcy.court',
#     'us:c10;bankruptcy.appellate.panel',
#     'us:c11:al.md;bankruptcy.court',
#     'us:c11:al.nd;bankruptcy.court',
#     'us:c11:al.sd;bankruptcy.court',
#     'us:c11:fl.md;bankruptcy.court',
#     'us:c11:fl.nd;bankruptcy.court',
#     'us:c11:fl.sd;bankruptcy.court',
#     'us:c11:ga.md;bankruptcy.court',
#     'us:c11:ga.nd;bankruptcy.court',
#     'us:c11:ga.sd;bankruptcy.court',
#     'us:c1:ma.d;bankruptcy.court',
#     'us:c1:me.d;bankruptcy.appellate.panel',
#     'us:c1:me.d;bankruptcy.court',
#     'us:c1:nh.d;bankruptcy.court',
#     'us:c1:pr.d;bankruptcy.court',
#     'us:c1:ri.d;bankruptcy.court',
#     'us:c1;bankruptcy.appellate.panel',
#     'us:c2:ct.d;bankruptcy.court',
#     'us:c2:ny.ed;bankruptcy.court',
#     'us:c2:ny.nd;bankruptcy.court',
#     'us:c2:ny.sd;bankruptcy.court',
#     'us:c2:ny.wd;bankruptcy.court',
#     'us:c2:vt.d;bankruptcy.court',
#     'us:c2;bankruptcy.appellate.panel',
#     'us:c3:de.d;bankruptcy.court',
#     'us:c3:nj.d;bankruptcy.court',
#     'us:c3:pa.ed;bankruptcy.court',
#     'us:c3:pa.md;bankruptcy.court',
#     'us:c3:pa.wd;bankruptcy.court',
#     'us:c3:vi.d;bankruptcy.court',
#     'us:c4:md.d;bankruptcy.court',
#     'us:c4:nc.ed;bankruptcy.court',
#     'us:c4:nc.md;bankruptcy.court',
#     'us:c4:nc.wd;bankruptcy.court',
#     'us:c4:sc.d;bankruptcy.court',
#     'us:c4:va.ed;bankruptcy.court',
#     'us:c4:va.wd;bankruptcy.court',
#     'us:c4:wv.nd;bankruptcy.court',
#     'us:c4:wv.sd;bankruptcy.court',
#     'us:c5:la.ed;bankruptcy.court',
#     'us:c5:la.md;bankruptcy.court',
#     'us:c5:la.wd;bankruptcy.court',
#     'us:c5:ms.nd;bankruptcy.court',
#     'us:c5:ms.sd;bankruptcy.court',
#     'us:c5:tx.ed;bankruptcy.court',
#     'us:c5:tx.nd;bankruptcy.court',
#     'us:c5:tx.sd;bankruptcy.court',
#     'us:c5:tx.wd;bankruptcy.court',
#     'us:c6:ky.ed;bankruptcy.court',
#     'us:c6:ky.wd;bankruptcy.court',
#     'us:c6:mi.ed;bankruptcy.court',
#     'us:c6:mi.wd;bankruptcy.court',
#     'us:c6:oh.nd;bankruptcy.court',
#     'us:c6:oh.sd;bankruptcy.court',
#     'us:c6:tn.d;bankruptcy.court',
#     'us:c6:tn.ed;bankruptcy.court',
#     'us:c6:tn.md;bankruptcy.court',
#     'us:c6:tn.wd;bankruptcy.court',
#     'us:c6;bankruptcy.appellate.panel',
#     'us:c7:il.cd;bankruptcy.court',
#     'us:c7:il.nd;bankruptcy.court',
#     'us:c7:il.sd;bankruptcy.court',
#     'us:c7:in.nd;bankruptcy.court',
#     'us:c7:in.sd;bankruptcy.court',
#     'us:c7:wi.ed;bankruptcy.court',
#     'us:c7:wi.wd;bankruptcy.court',
#     'us:c8:ar.ed;bankruptcy.court',
#     'us:c8:ar.wd;bankruptcy.court',
#     'us:c8:ia.nd;bankruptcy.court',
#     'us:c8:ia.sd;bankruptcy.court',
#     'us:c8:mn.d;bankruptcy.court',
#     'us:c8:mo.ed;bankruptcy.court',
#     'us:c8:mo.wd;bankruptcy.court',
#     'us:c8:nd.d;bankruptcy.court',
#     'us:c8:ne.d;bankruptcy.court',
#     'us:c8:sd.d;bankruptcy.court',
#     'us:c8;bankruptcy.appellate.panel',
#     'us:c9:ak.d;bankruptcy.court',
#     'us:c9:az.d;bankruptcy.court',
#     'us:c9:ca.cd;bankruptcy.court',
#     'us:c9:ca.ed;bankruptcy.court',
#     'us:c9:ca.nd;bankruptcy.court',
#     'us:c9:ca.sd;bankruptcy.court',
#     'us:c9:gu.d;bankruptcy.court',
#     'us:c9:hi.d;bankruptcy.court',
#     'us:c9:id.d;bankruptcy.court',
#     'us:c9:mp.d;bankruptcy.court',
#     'us:c9:mt.d;bankruptcy.court',
#     'us:c9:nv.d;bankruptcy.court',
#     'us:c9:or.d;bankruptcy.court',
#     'us:c9:wa.ed;bankruptcy.court',
#     'us:c9:wa.wd;bankruptcy.court',
#     'us:c9;bankruptcy.appellate.panel'],
#    'name': 'LexisNexis Bankruptcy Reporter',
#    'variations': {}}],
#  'Bankr. Rep (St. Louis B.A.)': [{'cite_type': 'specialty',
#    'editions': {'Bankr. Rep (St. Louis B.A.)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Bankruptcy Reports (St. Louis B.A.)',
#    'variations': {}}],
#  'Barb.': [{'cite_type': 'state',
#    'editions': {'Barb.': {'end': datetime.datetime(1877, 12, 31, 0, 0),
#      'start': datetime.datetime(1847, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;court.appeals'],
#    'name': "Barbour's Supreme Court Reports",
#    'variations': {'B.': 'Barb.',
#     'Barb. Rep.': 'Barb.',
#     'Barb.S.C.': 'Barb.'}}],
#  'Barb. Ch.': [{'cite_type': 'state',
#    'editions': {'Barb. Ch.': {'end': datetime.datetime(1848, 12, 31, 0, 0),
#      'start': datetime.datetime(1845, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;court.appeals'],
#    'name': "Barbour's Chancery Reports",
#    'variations': {'Barb. Ch. Rep.': 'Barb. Ch.',
#     'Barb.Ch.(N.Y.)': 'Barb. Ch.'}}],
#  'Baxt.': [{'cite_type': 'state',
#    'editions': {'Baxt.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:tn;supreme.court'],
#    'name': "Baxter's Reports (60-68 Tennessee)",
#    'variations': {'Bax.': 'Baxt.',
#     'Baxt. (Tenn.)': 'Baxt.',
#     'Baxter': 'Baxt.'}}],
#  'Bay': [{'cite_type': 'state',
#    'editions': {'Bay': {'end': datetime.datetime(1804, 12, 31, 0, 0),
#      'start': datetime.datetime(1783, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:sc;supreme.court'],
#    'name': 'South Carolina Reports, Bay',
#    'variations': {'S.C.L.(Bay)': 'Bay'}}],
#  "Bayard's Notebook": [{'cite_type': 'specialty',
#    'editions': {"Bayard's Notebook": {'end': datetime.datetime(1830, 12, 31, 0, 0),
#      'start': datetime.datetime(1792, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:de;'],
#    'name': "Bayard's Notebook",
#    'notes': 'Dates are rough, but wide, estimated from a series called Delaware Cases, which had these dates. See: http://www.worldcat.org/oclc/2882722',
#    'variations': {}}],
#  'Bedell': [{'cite_type': 'state',
#    'editions': {'Bedell': {'end': datetime.datetime(1909, 12, 31, 0, 0),
#      'start': datetime.datetime(1900, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;court.appeals'],
#    'name': 'Bedell',
#    'notes': 'Bedell, Edwin was the NY Reporter from 1900 until 1909. Date ranges are an estimate.',
#    'variations': {}}],
#  'Bee': [{'cite_type': 'scotus_early',
#    'editions': {'Bee': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us;supreme.court'],
#    'name': "Bee's United States (US) District Court Reports",
#    'variations': {}}],
#  'Beeler': [{'cite_type': 'state',
#    'editions': {'Beeler': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:tn;supreme.court'],
#    'name': "Beeler's Reports (Tenn.)",
#    'variations': {}}],
#  'Ben.': [{'cite_type': 'federal',
#    'editions': {'Ben.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Benedict United States District Reports',
#    'variations': {}}],
#  'Ben. Rev. Bd. Serv. (MB)': [{'cite_type': 'specialty',
#    'editions': {'Ben. Rev. Bd. Serv. (MB)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Benefits Review Board Service',
#    'variations': {}}],
#  'Bibb': [{'cite_type': 'state',
#    'editions': {'Bibb': {'end': datetime.datetime(1817, 12, 31, 0, 0),
#      'start': datetime.datetime(1808, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ky;supreme.court'],
#    'name': 'Kentucky Reports, Bibb',
#    'variations': {'Bibb Rep.': 'Bibb',
#     'Bibb(Ky.)': 'Bibb',
#     'Ky.(Bibb)': 'Bibb'}}],
#  'Binn.': [{'cite_type': 'state',
#    'editions': {'Binn.': {'end': datetime.datetime(1814, 12, 31, 0, 0),
#      'start': datetime.datetime(1799, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:pa;supreme.court'],
#    'name': 'Pennsylvania State Reports, Binney',
#    'variations': {'Bin.': 'Binn.',
#     'Bin. Rep.': 'Binn.',
#     'Binn. Rep.': 'Binn.',
#     'Binn.(Pa.)': 'Binn.'}}],
#  'Biss.': [{'cite_type': 'federal',
#    'editions': {'Biss.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c7:il.cd;district.court',
#     'us:c7:il.d;district.court',
#     'us:c7:il.ed;district.court',
#     'us:c7:il.nd;district.court',
#     'us:c7:il.sd;district.court',
#     'us:c7:in.d;district.court',
#     'us:c7:in.nd;district.court',
#     'us:c7:in.sd;district.court',
#     'us:c7:wi.ed;district.court',
#     'us:c7:wi.wd;district.court',
#     'us:c7;court.appeals'],
#    'name': "Bissell's United States Circuit Court Reports",
#    'variations': {'Biss': 'Biss.',
#     "Biss. (U.S.) Bissell's": 'Biss.',
#     'Bissell': 'Biss.'}}],
#  'Black': [{'cite_type': 'scotus_early',
#    'editions': {'Black': {'end': datetime.datetime(1862, 12, 31, 0, 0),
#      'start': datetime.datetime(1861, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us;supreme.court'],
#    'name': "Black's Supreme Court Reports",
#    'variations': {'Black R.': 'Black',
#     'Black Rep.': 'Black',
#     'U.S.(Black)': 'Black'}}],
#  'Blackf.': [{'cite_type': 'state',
#    'editions': {'Blackf.': {'end': datetime.datetime(1847, 12, 31, 0, 0),
#      'start': datetime.datetime(1817, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:in;supreme.court'],
#    'name': 'Indiana Reports, Blackford',
#    'variations': {'Black.': 'Blackf.',
#     'Black. Rep.': 'Blackf.',
#     'Blackf. Rep.': 'Blackf.',
#     'Blackf.(Ind.)': 'Blackf.'}}],
#  'Bland': [{'cite_type': 'state',
#    'editions': {'Bland': {'end': datetime.datetime(1832, 12, 31, 0, 0),
#      'start': datetime.datetime(1797, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:md;court.appeals'],
#    'name': 'Reports of cases decided in the High court of chancery of Maryland (Bland, Chancellor)',
#    'variations': {}}],
#  'Blatchf.': [{'cite_type': 'federal',
#    'editions': {'Blatchf.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': "Blatchford's United States Circuit Court Reports",
#    'variations': {'Bl. C.C.': 'Blatchf.',
#     'Bl. C.C.R.': 'Blatchf.',
#     'Blat. C.C.R.': 'Blatchf.',
#     'Blatch': 'Blatchf.',
#     'Blatch. (U.S. Cir. Ct.)': 'Blatchf.',
#     'Blatchf. (U.S. Circ. Ct.)': 'Blatchf.',
#     'Blatchf. C.C.': 'Blatchf.',
#     'Blatchf. C.C. Rep.': 'Blatchf.'}}],
#  'Blue Sky L. Rep. (CCH)': [{'cite_type': 'specialty',
#    'editions': {'Blue Sky L. Rep. (CCH)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Blue Sky Law Reports',
#    'variations': {}}],
#  'Blume Sup. Ct. Trans.': [{'cite_type': 'state',
#    'editions': {'Blume Sup. Ct. Trans.': {'end': datetime.datetime(1836, 12, 31, 0, 0),
#      'start': datetime.datetime(1805, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:mi;supreme.court'],
#    'name': 'Blume, Supreme Court Transactions',
#    'variations': {'Blume Sup.Ct.Trans.': 'Blume Sup. Ct. Trans.'}}],
#  'Blume Unrep. Op.': [{'cite_type': 'state',
#    'editions': {'Blume Unrep. Op.': {'end': datetime.datetime(1843, 12, 31, 0, 0),
#      'start': datetime.datetime(1836, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:mi;supreme.court'],
#    'name': 'Blume, Unreported Opinions',
#    'variations': {'Blume Op.': 'Blume Unrep. Op.'}}],
#  'Bond': [{'cite_type': 'federal',
#    'editions': {'Bond': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': "Bond's United States (US) Circuit Reports",
#    'variations': {}}],
#  'Bosw.': [{'cite_type': 'state',
#    'editions': {'Bosw.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ny;superior.court'],
#    'name': "Bosworth's Reports (14-23 New York Superior)",
#    'variations': {}}],
#  'Boyce': [{'cite_type': 'state',
#    'editions': {'Boyce': {'end': datetime.datetime(1920, 12, 31, 0, 0),
#      'start': datetime.datetime(1909, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:de;supreme.court'],
#    'name': 'Delaware Reports, Boyce',
#    'variations': {'Del.(Boyce)': 'Boyce'}}],
#  'Bradf.': [{'cite_type': 'state',
#    'editions': {'Bradf.': {'end': datetime.datetime(1841, 12, 31, 0, 0),
#      'start': datetime.datetime(1838, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ia;supreme.court'],
#    'name': 'Iowa Reports, Bradford',
#    'variations': {'Brad.': 'Bradf.', 'Bradford': 'Bradf.'}}],
#  'Brayt.': [{'cite_type': 'state',
#    'editions': {'Brayt.': {'end': datetime.datetime(1819, 12, 31, 0, 0),
#      'start': datetime.datetime(1815, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:vt;supreme.court'],
#    'name': 'Vermont Reports, Brayton',
#    'variations': {'Brayton (Vt.)': 'Brayt.'}}],
#  'Breese': [{'cite_type': 'state',
#    'editions': {'Breese': {'end': datetime.datetime(1831, 12, 31, 0, 0),
# ...
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;court.appeals.armed.forces'],
#    'name': 'LexisNexis United States Court of Military Commission Review',
#    'variations': {}}],
#  'U.S. Claims LEXIS': [{'cite_type': 'specialty',
#    'editions': {'U.S. Claims LEXIS': {'end': None,
#      'start': datetime.datetime(1982, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;claims.court'],
#    'name': 'LexisNexis United States Claims Court',
#    'variations': {'U.S. Cl. Ct. LEXIS': 'U.S. Claims LEXIS'}}],
#  'U.S. Commerce Ct. LEXIS': [{'cite_type': 'specialty',
#    'editions': {'U.S. Commerce Ct. LEXIS': {'end': datetime.datetime(1913, 12, 31, 0, 0),
#      'start': datetime.datetime(1910, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;court.commerce'],
#    'name': 'LexisNexis United States Commerce Court',
#    'variations': {}}],
#  'U.S. Ct. Cl. LEXIS': [{'cite_type': 'specialty',
#    'editions': {'U.S. Ct. Cl. LEXIS': {'end': None,
#      'start': datetime.datetime(1856, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;court.claims'],
#    'name': 'LexisNexis United States Court of Claims',
#    'variations': {}}],
#  'U.S. Dist. LEXIS': [{'cite_type': 'specialty_lexis',
#    'editions': {'U.S. Dist. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c0:dc.d;district.court',
#     'us:c10:co.d;district.court',
#     'us:c10:ks.d;district.court',
#     'us:c10:nm.d;district.court',
#     'us:c10:ok.ed;district.court',
#     'us:c10:ut.d;district.court',
#     'us:c10:wy.d;district.court',
#     'us:c11:al.md;district.court',
#     'us:c11:fl.md;district.court',
#     'us:c11:ga.md;district.court',
#     'us:c1:ma.d;district.court',
#     'us:c1:me.d;district.court',
#     'us:c1:nh.d;district.court',
#     'us:c1:pr.d;district.court',
#     'us:c1:ri.d;district.court',
#     'us:c2:ct.d;district.court',
#     'us:c2:ny.ed;district.court',
#     'us:c2:vt.d;district.court',
#     'us:c3:de.d;district.court',
#     'us:c3:nj.d;district.court',
#     'us:c3:pa.d;district.court',
#     'us:c3:vi.d;district.court',
#     'us:c4:md.d;district.court',
#     'us:c4:nc.ed;district.court',
#     'us:c4:sc.d;district.court',
#     'us:c4:sc.ed;district.court',
#     'us:c4:sc.wd;district.court',
#     'us:c4:va.ed;district.court',
#     'us:c4:wv.nd;district.court',
#     'us:c5:la.ed;district.court',
#     'us:c5:ms.nd;district.court',
#     'us:c5:pz.d;district.court',
#     'us:c5:tx.ed;district.court',
#     'us:c6:ky.ed;district.court',
#     'us:c6:mi.ed;district.court',
#     'us:c6:oh.d;district.court',
#     'us:c6:tn.d;district.court',
#     'us:c7:il.cd;district.court',
#     'us:c7:in.d;district.court',
#     'us:c7:wi.ed;district.court',
#     'us:c8:ar.ed;district.court',
#     'us:c8:ia.nd;district.court',
#     'us:c8:mn.d;district.court',
#     'us:c8:mo.cd;district.court',
#     'us:c8:nd.d;district.court',
#     'us:c8:ne.d;district.court',
#     'us:c8:sd.d;district.court',
#     'us:c9:ak.d;district.court',
#     'us:c9:az.d;district.court',
#     'us:c9:ca.cd;district.court',
#     'us:c9:gu.d;district.court',
#     'us:c9:hi.d;district.court',
#     'us:c9:id.d;district.court',
#     'us:c9:mp.d;district.court',
#     'us:c9:mt.d;district.court',
#     'us:c9:nv.d;district.court',
#     'us:c9:or.d;district.court',
#     'us:c9:wa.ed;district.court'],
#    'name': 'LexisNexis U.S. District Court Citation',
#    'variations': {}}],
#  'U.S. LEXIS': [{'cite_type': 'specialty_lexis',
#    'editions': {'U.S. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us;supreme.court'],
#    'name': 'Lexis SCOTUS Citation',
#    'publisher': 'RELX Group',
#    'variations': {}}],
#  'U.S. Law Int.': [{'cite_type': 'federal',
#    'editions': {'U.S. Law Int.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'United States Law Intelligencer and Review (Providence and Philadelphia)',
#    'variations': {}}],
#  'U.S. Tax Cas. (CCH)': [{'cite_type': 'specialty',
#    'editions': {'U.S. Tax Cas. (CCH)': {'end': None,
#      'regexes': ['$full_cite_cch'],
#      'start': datetime.datetime(1900, 1, 1, 0, 0)}},
#    'examples': ['57-2 U.S. Tax Cas. (CCH) P9816',
#     '2001-1 U.S. Tax Cas. (CCH) P54,209'],
#    'mlz_jurisdiction': ['us:c;tax.court'],
#    'name': 'United States (US) Tax Cases (CCH)',
#    'variations': {}}],
#  'U.S. Tax Ct. LEXIS': [{'cite_type': 'specialty_lexis',
#    'editions': {'U.S. Tax Ct. LEXIS': {'end': None,
#      'start': datetime.datetime(1924, 1, 1, 0, 0)}},
#    'examples': ['2002 U.S. Tax Ct. LEXIS 28'],
#    'mlz_jurisdiction': ['us:c;tax.court'],
#    'name': 'United States (US) Tax Cases Lexis',
#    'variations': {}}],
#  'U.S. Tax Rep. (RIA)': [{'cite_type': 'specialty',
#    'editions': {'U.S. Tax Rep. (RIA)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'U.S. Tax Reporter',
#    'variations': {}}],
#  'U.S. Vet. App. LEXIS': [{'cite_type': 'specialty',
#    'editions': {'U.S. Vet. App. LEXIS': {'end': None,
#      'start': datetime.datetime(1990, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;board.veterans.appeals'],
#    'name': 'LexisNexis United States Board of Veteran Appeals',
#    'variations': {'U.S. App. Vet. Claims LEXIS': 'U.S. Vet. App. LEXIS'}}],
#  'U.S.L.W.': [{'cite_type': 'specialty',
#    'editions': {'U.S.L.W.': {'end': None,
#      'start': datetime.datetime(1933, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us;supreme.court'],
#    'name': 'United States Law Week',
#    'variations': {'USLW': 'U.S.L.W.'}}],
#  'U.S.L.W. (BNA)': [{'cite_type': 'specialty',
#    'editions': {'U.S.L.W. (BNA)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'The United States Law Week',
#    'variations': {}}],
#  'U.S.P.Q. (BNA)': [{'cite_type': 'specialty',
#    'editions': {'U.S.P.Q. (BNA)': {'end': datetime.datetime(1987, 12, 31, 0, 0),
#      'start': datetime.datetime(1913, 1, 1, 0, 0)},
#     'U.S.P.Q. 2d (BNA)': {'end': None,
#      'start': datetime.datetime(1987, 1, 1, 0, 0)}},
#    'href': 'http://www.bna.com/iprc_uspq/',
#    'mlz_jurisdiction': [],
#    'name': 'The United States Patents Quarterly',
#    'variations': {'U.S.P.Q.': 'U.S.P.Q. (BNA)',
#     'U.S.P.Q.2D (BNA)': 'U.S.P.Q. 2d (BNA)',
#     'U.S.P.Q.2d': 'U.S.P.Q. 2d (BNA)',
#     'U.S.P.Q.2d (BNA)': 'U.S.P.Q. 2d (BNA)',
#     'USPQ': 'U.S.P.Q. (BNA)',
#     'USPQ (BNA)': 'U.S.P.Q. (BNA)',
#     'USPQ 2d': 'U.S.P.Q. 2d (BNA)',
#     'USPQ 2d (BNA)': 'U.S.P.Q. 2d (BNA)'}}],
#  'USCMA': [{'cite_type': 'specialty',
#    'editions': {'USCMA': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;court.appeals.armed.forces'],
#    'name': 'Official Reports, United States Court of Military Appeals',
#    'variations': {'U.S.C.M.A.': 'USCMA'}}],
#  'UT': [{'cite_type': 'neutral',
#    'editions': {'UT': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ut;supreme.court'],
#    'name': 'Utah Neutral Citation',
#    'variations': {}}],
#  'UT App': [{'cite_type': 'neutral',
#    'editions': {'UT App': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ut;court.appeals'],
#    'name': 'Utah Neutral Citation',
#    'variations': {}}],
#  'Unemployment Ins. Rep.': [{'cite_type': 'specialty',
#    'editions': {'Unemployment Ins. Rep.': {'end': None,
#      'regexes': ['$volume_with_alpha_suffix_optional$reporter,? (?P<jurisdiction>\\(?[A-Z][a-zA-Z .]+\\)? )?$paragraph_marker_optional$page_with_commas_or_periods'],
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'examples': ['CCH Unemployment Ins. Rep. ¶ 15,419',
#     '1 CCH Unemployment Ins. Rep. para. 14,387',
#     '8 CCH, Unemployment Ins. Rep. W. Va. par. 8090',
#     '1A CCH, Unemployment Ins. Rep. (Ala.) par. 1950.74',
#     '4 CCH Unemployment Ins. Rep., Me. ¶ 1995.05'],
#    'mlz_jurisdiction': [],
#    'name': 'Unemployment Insurance Reports (CCH)',
#    'variations': {'CCH Unemployment Ins. Rep.': 'Unemployment Ins. Rep.',
#     'CCH, Unemployment Ins. Rep.': 'Unemployment Ins. Rep.',
#     'Unempl. Ins. Rep. (CCH)': 'Unemployment Ins. Rep.',
#     'Unemployment Ins. Rep. (CCH)': 'Unemployment Ins. Rep.'}}],
#  'Union Lab. Rep. (BNA)': [{'cite_type': 'specialty',
#    'editions': {'Union Lab. Rep. (BNA)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Union Labor Report',
#    'variations': {}}],
#  'Utah': [{'cite_type': 'state',
#    'editions': {'Utah': {'end': datetime.datetime(1974, 12, 31, 0, 0),
#      'start': datetime.datetime(1851, 1, 1, 0, 0)},
#     'Utah 2d': {'end': datetime.datetime(1974, 12, 31, 0, 0),
#      'start': datetime.datetime(1851, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ut;supreme.court'],
#    'name': 'Utah Reports',
#    'variations': {}}],
#  'Utah Adv. Rep.': [{'cite_type': 'state',
#    'editions': {'Utah Adv. Rep.': {'end': None,
#      'start': datetime.datetime(1987, 1, 1, 0, 0)}},
#    'href': 'http://www.code-co.com/',
#    'mlz_jurisdiction': [],
#    'name': 'Utah Advance Reports',
#    'publisher': 'Code Co.',
#    'variations': {}}],
#  'Utah App. LEXIS': [{'cite_type': 'state',
#    'editions': {'Utah App. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ut;appeals.court'],
#    'name': 'LexisNexis Utah Appeals Court',
#    'variations': {}}],
#  'Utah LEXIS': [{'cite_type': 'state',
#    'editions': {'Utah LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:ut;supreme.court'],
#    'name': 'LexisNexis Utah Supreme Court',
#    'variations': {}}],
#  'Util. L. Rep. (CCH)': [{'cite_type': 'specialty',
#    'editions': {'Util. L. Rep. (CCH)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': [],
#    'name': 'Utilities Law Reports',
#    'variations': {}}],
#  'V.I.': [{'cite_type': 'state',
#    'editions': {'V.I.': {'end': None,
#      'start': datetime.datetime(1917, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c3:vi.d;district.court'],
#    'name': 'Virgin Islands Reports',
#    'variations': {}}],
#  'V.I. LEXIS': [{'cite_type': 'state',
#    'editions': {'V.I. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:vi;supreme.court'],
#    'name': 'LexisNexis Virgin Island Supreme Court',
#    'variations': {}}],
#  'V.I. Supreme LEXIS': [{'cite_type': 'state',
#    'editions': {'V.I. Supreme LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:vi;supreme.court'],
#    'name': 'LexisNexis Virgin Islands Supreme Court',
#    'variations': {}}],
#  'VT': [{'cite_type': 'neutral',
#    'editions': {'VT': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:vt;supreme.court'],
#    'name': 'Vermont Neutral Citation',
#    'variations': {}}],
#  'Va.': [{'cite_type': 'state',
#    'editions': {'Va.': {'end': None,
#      'regexes': ['$full_cite',
#       '$volume $reporter \\($volume_nominative(?P<reporter_nominative>Gratt\\.|Rob\\.|Leigh|Rand\\.|Gilmer|Munf\\.|Hen\\. & M\\.|Call|Va\\. Cas\\.|Wash\\.)\\) $page'],
#      'start': datetime.datetime(1880, 1, 1, 0, 0)}},
#    'examples': ['1 Va. 1', '21 Va. (Gilmer) 456', '1 Va. (1 Wash.) 456'],
#    'mlz_jurisdiction': ['us:va;supreme.court'],
#    'name': 'Virginia Reports',
#    'variations': {'V.': 'Va.', 'Va. Rep.': 'Va.', 'Virg.': 'Va.'}}],
#  'Va. App.': [{'cite_type': 'state',
#    'editions': {'Va. App.': {'end': None,
#      'start': datetime.datetime(1985, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:va;supreme.court'],
#    'name': 'Virginia Court of Appeals Reports',
#    'variations': {'Va.App.': 'Va. App.'}}],
#  'Va. App. LEXIS': [{'cite_type': 'state',
#    'editions': {'Va. App. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:va;supreme.court'],
#    'name': 'LexisNexis Virginia Supreme Court',
#    'variations': {}}],
#  'Va. Cas.': [{'cite_type': 'state',
#    'editions': {'Va. Cas.': {'end': datetime.datetime(1826, 12, 31, 0, 0),
#      'start': datetime.datetime(1789, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:va;supreme.court'],
#    'name': 'Virginia Cases, Criminal',
#    'variations': {}}],
#  'Va. Cir.': [{'cite_type': 'state',
#    'editions': {'Va. Cir.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:va;circuit.court'],
#    'name': 'Virginia Circuit Court Opinions',
#    'variations': {}}],
#  'Va. Cir. LEXIS': [{'cite_type': 'state',
#    'editions': {'Va. Cir. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:va;circuit.court'],
#    'name': 'LexisNexis Virgina Circuit Court',
#    'variations': {}}],
#  'Va. Dec.': [{'cite_type': 'state',
#    'editions': {'Va. Dec.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:va;supreme.court'],
#    'name': 'Virginia Decisions',
#    'variations': {'Va.Dec.': 'Va. Dec.'}}],
#  'Va. LEXIS': [{'cite_type': 'state',
#    'editions': {'Va. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:va;court.supreme'],
#    'name': 'LexisNexis Virginia Supreme Court',
#    'variations': {}}],
#  'Va. Law J.': [{'cite_type': 'state',
#    'editions': {'Va. Law J.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:va;supreme.court'],
#    'name': 'Virginia Law Journal',
#    'variations': {'Vir. L.J.': 'Va. Law J.'}}],
#  'Va. Law Rep.': [{'cite_type': 'state',
#    'editions': {'Va. Law Rep.': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:va;supreme.court'],
#    'name': 'Virginia Law Reports',
#    'variations': {}}],
#  'Va. Unpub. LEXIS': [{'cite_type': 'state',
#    'editions': {'Va. Unpub. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:in;supreme.court'],
#    'name': 'LexisNexis Virginia Supreme Court Unpublished',
#    'variations': {}}],
#  'Van Ness': [{'cite_type': 'state',
#    'editions': {'Van Ness': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c2:ny.ed;district.court',
#     'us:c2:ny.nd;district.court',
#     'us:c2:ny.sd;district.court',
#     'us:c2:ny.wd;district.court'],
#    'name': "Van Ness' Prize Cases, United States (US) District Court, District of New York (NY)",
#    'variations': {}}],
#  'Vet. App.': [{'cite_type': 'specialty',
#    'editions': {'Vet. App.': {'end': None,
#      'start': datetime.datetime(1990, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:c;board.veterans.appeals'],
#    'name': 'Veterans Appeals Reporter',
#    'variations': {'Vet.App.': 'Vet. App.'}}],
#  'Vroom': [{'cite_type': 'state',
#    'editions': {'Vroom': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'Vroom (G.D.W)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)},
#     'Vroom (P.D.)': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:nj;supreme.court'],
#    'name': "Vroom's Reports",
#    'variations': {'Vr.': 'Vroom',
#     'Vroom (N.J.)': 'Vroom',
#     'Vroom.': 'Vroom'}}],
#  'Vt.': [{'cite_type': 'state',
#    'editions': {'Vt.': {'end': None,
#      'start': datetime.datetime(1826, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:vt;supreme.court'],
#    'name': 'Vermont Reports',
#    'variations': {'V.R.': 'Vt.',
#     'Verm.': 'Vt.',
#     'Verm. Rep.': 'Vt.',
#     'Vt. Rep.': 'Vt.'}}],
#  'Vt. LEXIS': [{'cite_type': 'state',
#    'editions': {'Vt. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:vt;supreme.court'],
#    'name': 'LexisNexis Vermont Supreme Court',
#    'variations': {}}],
#  'Vt. Super. LEXIS': [{'cite_type': 'state',
#    'editions': {'Vt. Super. LEXIS': {'end': None,
#      'start': datetime.datetime(1750, 1, 1, 0, 0)}},
#    'mlz_jurisdiction': ['us:vt;superior.court'],
#    'name': 'LexisNexis Vermont Superior Court',
#    'variations': {}}],
#  ...}

# %% [markdown]
# Obviously there is a lot of data in those libraries. Here is the [reporters_db data](https://github.com/freelawproject/reporters-db/tree/main/reporters_db/data). Here is the [courts-db data](https://github.com/freelawproject/courts-db/tree/main/courts_db/data). Unsurprisingly, Kelly (our example above) is not used in the reporters database. But it could be.

# %% [markdown]
# ## Trying to do something real

# %% [markdown]
# We have some sample treatises. So let's see if we can extract citations from one of those.

# %%
with open('../sample-treatises/Pomeroy, Remedies, 1876.txt') as f:
    treatise = f.read()

print(treatise[:5000])
# Out:
# Disclaimer: This file is generated using OCR (optical character recognition) and/or HTR (handwritten text recognition), which are technologies that convert images of text into text. While the technologies are good at deciphering legible text, there are limitations and some text may not have been extracted correctly.
# Remedies and remedial rights by the civil action, according to the reformed American procedure : a treatise adapted to use in all the states and territories where that system prevails
# c REME D IES,AND REMEDIAL RIGHTS,DY THE CIVIL ACTION,,ACCOI1DINO TO THE REFORMED AMERICAN PROCEDURE.,A TREATISE ADAPTED TO USE IN ALL THE STATES AND TERRITORIES,WHERE TIIAT SYSTEM PREVAILS.,BY JOHN NORTON POMEROY, LL.D., AUTROR OP "AN INTIODUCTrIOT TO MUNICIPAL LAIV," ' AN INTRODUCnOTI,TO CONBTITUTIONAL LAW," ETC., ETC. B,5 /Osrp BOSTON: LITTLE, BROWN, AND COMPANY.,1876.,1
# *,;,)/~. . . Entorole according to Act of Congress, In thq year 1870, by,JOIlt0 NOnTON 1'OlIF.OY, In tle Omce of the Librarian of Congress, at Wnahington.,: / s D,Cambriaso Fress of nehIa Wilson and Son.
# TO .AARON J. VANDERPOEL, ESQ.,,OF TIlE NEW YORK BAR, THIS BOOK IS INSCRIBED ALIKE AS A TRIIIUTE TO HIS HIGH PHOPISSIONAL,CHARACTER, AND AS AN EX'RESSION OF TIlE AUTHOR'S,PERSONAL BXOARD.,.
# PREFACE. THE new procedure which was devised by the codifiers and inaugurated by the Legislature of New York, in the year 1848, now prevails in more than twenty other States and Territories of this country, and may, therefore, be properly termed " The Re- formed American System of Procedure." After a most careful consideration, and the most cautious and deliberate examination by a commission composed of the ablest judges and barristers, it has finally been accepted in its essential features and elements by the British Parliament, and has recently displaced the time-hon- ored methods of the common-law and the equity courts in Eng- land. This fact alone maybe regarded as decisive of its intLinsic excellence, as conclusively demonstrating that it is founded upon natural and true principles; that it embodies rational notions in respect to the manner of conducting judicial controversies be- tween private litigants; and that, in its conception and design, it is far superior to the artificial, technical, and arbitrary modes which had so long been looked upon as perfect by generations of English and American lawyers. It is shown in the Introductory Chapter of the present work that this whole course of reform is but a repetition, not simply in a general outline, but even in the minute details, of what took place in the jurisprudence of Rome; so that the modern legislation has, in this respect, merely fol- lowed an inevitable law of progress, which always works out the same results under the same social conditions and circumstances.,Although the codes which have been enacted in the various States and Territories sometimes differ slightly from each other in respect to the minor measures and steps of practice, and al- though some of them, in reference to certain special matters, have
# more freely carried out the original and underlying theory to its logical results, and have by distinct provisions expressly abro- gated particular dogmas of the old law, which in other States are only included in the general language of the statute, and are thus left within the domain of judicial construction, yet in all its essential notions and fundamental doctrines the reformed proce- dure is one and the same wherever it prevails, either in the United States or in England. The " Civil Action" which it has created and introduced as the single and sufficient instrument for the trial of all judicial.controversies between private suitors and for the pursuit oÂ£ all judicial remedies is the same in con- ception, in form, and in substance, possessing the same charac- teristic features, governed by the same elementary rules, and embodying the same organic principles. Ho1w_ comp.iely the ( reformed sy stem is severed from the ancient common-laws modes,,o_;_entirely it abandons all the arbitrary, formal, and technical notions which were their very essence and life, and how firmly it P rests upon natural and necessary facts as its foundations, is shown in the Introductory Chapter and in other portions of this work. \ It is impossible, therefore, that its full benefits can be attained, : and that-fuil scope can be given to its original. purpose, until the courts and the profession shall accept it in its simplicity, and shall cease to obstruct its efficient operation and to interrupt its free movements by antiquated dogmas and rejected doctrines drawn from the system which it has thoroughly overthrown and supplanted.,'lhe design of the author is to present the entire remedial department of the law - the remedies and remedial rights - according to the reformed procedure. The volume now sub- mitted to the profession, although in itself a complete and inde- pendent work, accomplishes a part of this full

# %% [markdown]
# Now that we have the text, we will clean it, find the citations, and reduce the citations down to unique instances. The [eyecite tutorial](https://github.com/freelawproject/eyecite/blob/main/TUTORIAL.ipynb) provides a guide.

# %%
cleaned_text = eyecite.clean_text(treatise, ['underscores', 'all_whitespace'])
tokenizer = eyecite.tokenizers.HyperscanTokenizer(cache_dir='/tmp/test_cache')
citations = eyecite.get_citations(cleaned_text, tokenizer=tokenizer)
resolutions = eyecite.resolve_citations(citations)
print(f'Found {len(citations)} citations and resolved them into {len(resolutions)} groups.')
# Out:
# Found 7030 citations and resolved them into 3276 groups.

# %% [markdown]
# That seems like a reasonable result, keeping in mind the question of reporters.
#
# Now let's just print out a list of the citations.

# %%
for resource in resolutions.keys():
    print(resource.citation.corrected_citation())
# Out:
# 32 Cal. 172
# 31 Barb. 288
# 36 N.Y. 613
# 31 N.Y. 664
# 28 Barb. 382
# 4 Lans. 164
# 2 Vt. 9
# 19 Ind. 339
# 19 Ind. 418
# 37 Mo. 141
# 81 Ind. 20
# 43 Ind. 167
# 48 Ind. 12
# 39 Cal. 292
# 17 Abb. Pr. 169
# 39 Mo. 145
# 21 Ind. 137
# 3 Lans. 116
# 2 Barb. 258
# 37 Iowa, 454
# 16 Ired. 89
# 2 Duv. 800
# 46 Cal. 482
# 1 N.Y. 305
# 44 N.Y. 228
# 88 N.Y. 280
# 11 How. Pr. 218
# 11 Ohio St. 874
# 7 N.Y. 476
# 48 Ind. 496
# 44 Mo. 263
# 16 Ohio St. 146
# 16 N.Y. 416
# 46 N.Y. 688
# 41 Ind. 164
# 41 Mo. 484
# 48 Mo. 819
# 9 Kan. 401
# 45 Ind. 156
# 26 Ind. 461
# 68 Barb. 288
# 28 N.Y. 600
# 2 Duv. 480
# 16 Barb. 633
# 21 Ala. 487
# 47 N.Y. 487
# 44 Cal. 809
# 28 How. Pr. 324
# 8 How. Pr. 434
# 20 Iowa, 66
# 18 Iowa, 241
# 4 Kan. 211
# 10 Cal. 150
# 4 Wend. 406
# 17 How. Pr. 76
# 8 Minn. 254
# 32 Ind. 408
# 26 Mo. 210
# 29 N.Y. 494
# 3 Abb. Pr. 184
# 9 Abb. Pr. 353
# 29 Mo. 429
# 23 Ohio St. 543
# 2 Kan. 135
# 47 N.Y. 860
# 44 N.Y. 63
# 31 Ind. 270
# 18 Barb. 264
# 63 Barb. 454
# 51 Barb. 466
# 1 Kan. 803
# 4 Abb. Pr. 176
# 44 Barb. 577
# 2 Duer, 160
# 2 Paige Ch., 278
# 36 Me. 50
# 29 Iowa, 631
# 16 Barb. 64
# 7 Cal. 661
# 1 Daly, 469
# 6 Mass. 460
# 13 Ind. 63
# 16 Ind. 479
# 54 Barb. 605
# 21 Ind. 427
# 40 N.Y. 314
# 37 N.Y. 35
# 7 Bosw. 664
# 6 How. Pr. 379
# 13 N.Y. 309
# 20 N.Y. 355
# 11 How. Pr. 216
# 42 Cal. 129
# 18 B. Mon. 635
# 6 Lans. 25
# 33 Barb. 320
# 42 N.Y. 816
# 40 Cal. 851
# 24 N.Y. 40
# 22 Ind. 854
# 16 Abb. Pr. 420
# 6 Cal. 299
# 18 Cal. 334
# 30 Cal. 486
# 13 Ohio St. 72
# 34 Iowa, 452
# 57 N.Y. 587
# 21 N.Y. 200
# 38 N.Y. 21
# 11 N.Y. 237
# 6 Bosw. 29
# 37 N.Y. 409
# 2 Iowa, 423
# 39 Mo. 385
# 47 N.Y. 577
# 8 Paige Ch., 146
# 51 Me. 348
# 46 Ind. 544
